# %% [markdown]
# # Machine Learning - Project

# %% [markdown]
# ## Objective:
# We will create a model for **Credit Card Fraud Detection** using Python.
# Fake news refers to information content that is false, misleading or whose source cannot be verified.

# %% [markdown]
# ## Make necessary imports:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, log_loss

# %%
#importing datasets  
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ## Columns in Dataset
# **Time**: Number of seconds elapsed between this transaction and the first transaction in the dataset
#
# **v1-v28**: may be result of a PCA Dimensionality reduction to protect user identities and sensitive features
#
# **Amount**: Transaction amount
#
# **Class**: 1 for fraudulent transactions, 0 otherwise

# %% [markdown]
# We will use **Logistic Regression** as we need to predict categorical dependent variable **Class**

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %% [markdown]
# Check the size of the dataframe/table as it would decide whether we can drop the rows with null values without affecting the size of our dataset or not

# %%
data.shape
# Out:
# (284807, 31)

# %%
#Checking the total number of missing values in each of the columns.
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# We have no missing data!

# %% [markdown]
# We will check the statistics and correlation between all the columns and decide which columns do not play the role in determining the fraud transaction.

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Now Let’s explore the unique values in the each category using below code.

# %%
ax = sns.countplot(data=data,
              x='Class',
              order=data['Class'].value_counts().index)
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
correlation_matrix = data.corr(method = "pearson")
correlation_matrix
# Out:
#             Time            V1            V2            V3            V4
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01  \
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
#Extracting Independent and dependent Variable  
x_data = data.drop('Class', axis = 1)
y_data = data['Class']

# %% [markdown]
# Now we randomly split our data into training and testing data  using the function <b>train_test_split</b>.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.25, random_state=1)

print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 71202
# number of training samples: 213605

# %%
y_train_values = y_train.value_counts()
y_test_values = y_test.value_counts()
print(y_train_values)
print(y_test_values)
# Out:
# Class
# 0    213224
# 1       381
# Name: count, dtype: int64
# Class
# 0    71091
# 1      111
# Name: count, dtype: int64

# %%
x_train_time = x_train['Time'].array.reshape(-1, 1)
x_train_v1 = x_train['V1'].array.reshape(-1, 1)
x_train_v2 = x_train['V2'].array.reshape(-1, 1)
x_train_v3 = x_train['V3'].array.reshape(-1, 1)
x_train_v4 = x_train['V4'].array.reshape(-1, 1)
x_train_v5 = x_train['V5'].array.reshape(-1, 1)
x_train_v6 = x_train['V6'].array.reshape(-1, 1)
x_train_v7 = x_train['V7'].array.reshape(-1, 1)
x_train_v8 = x_train['V8'].array.reshape(-1, 1)
x_train_v9 = x_train['V9'].array.reshape(-1, 1)
x_train_v10 = x_train['V10'].array.reshape(-1, 1)
x_train_v11 = x_train['V11'].array.reshape(-1, 1)
x_train_v12 = x_train['V12'].array.reshape(-1, 1)
x_train_v13 = x_train['V13'].array.reshape(-1, 1)
x_train_v14 = x_train['V14'].array.reshape(-1, 1)
x_train_v15 = x_train['V15'].array.reshape(-1, 1)
x_train_v16 = x_train['V16'].array.reshape(-1, 1)
x_train_v17 = x_train['V17'].array.reshape(-1, 1)
x_train_v18 = x_train['V18'].array.reshape(-1, 1)
x_train_v19 = x_train['V19'].array.reshape(-1, 1)
x_train_v20 = x_train['V20'].array.reshape(-1, 1)
x_train_v21 = x_train['V21'].array.reshape(-1, 1)
x_train_v22 = x_train['V22'].array.reshape(-1, 1)
x_train_v23 = x_train['V23'].array.reshape(-1, 1)
x_train_v24 = x_train['V24'].array.reshape(-1, 1)
x_train_v25 = x_train['V25'].array.reshape(-1, 1)
x_train_v26 = x_train['V26'].array.reshape(-1, 1)
x_train_v27 = x_train['V27'].array.reshape(-1, 1)
x_train_v28 = x_train['V28'].array.reshape(-1, 1)
x_train_amt = x_train['Amount'].array.reshape(-1, 1)

x_test_time = x_test['Time'].array.reshape(-1, 1)
x_test_v1 = x_test['V1'].array.reshape(-1, 1)
x_test_v2 = x_test['V2'].array.reshape(-1, 1)
x_test_v3 = x_test['V3'].array.reshape(-1, 1)
x_test_v4 = x_test['V4'].array.reshape(-1, 1)
x_test_v5 = x_test['V5'].array.reshape(-1, 1)
x_test_v6 = x_test['V6'].array.reshape(-1, 1)
x_test_v7 = x_test['V7'].array.reshape(-1, 1)
x_test_v8 = x_test['V8'].array.reshape(-1, 1)
x_test_v9 = x_test['V9'].array.reshape(-1, 1)
x_test_v10 = x_test['V10'].array.reshape(-1, 1)
x_test_v11 = x_test['V11'].array.reshape(-1, 1)
x_test_v12 = x_test['V12'].array.reshape(-1, 1)
x_test_v13 = x_test['V13'].array.reshape(-1, 1)
x_test_v14 = x_test['V14'].array.reshape(-1, 1)
x_test_v15 = x_test['V15'].array.reshape(-1, 1)
x_test_v16 = x_test['V16'].array.reshape(-1, 1)
x_test_v17 = x_test['V17'].array.reshape(-1, 1)
x_test_v18 = x_test['V18'].array.reshape(-1, 1)
x_test_v19 = x_test['V19'].array.reshape(-1, 1)
x_test_v20 = x_test['V20'].array.reshape(-1, 1)
x_test_v21 = x_test['V21'].array.reshape(-1, 1)
x_test_v22 = x_test['V22'].array.reshape(-1, 1)
x_test_v23 = x_test['V23'].array.reshape(-1, 1)
x_test_v24 = x_test['V24'].array.reshape(-1, 1)
x_test_v25 = x_test['V25'].array.reshape(-1, 1)
x_test_v26 = x_test['V26'].array.reshape(-1, 1)
x_test_v27 = x_test['V27'].array.reshape(-1, 1)
x_test_v28 = x_test['V28'].array.reshape(-1, 1)
x_test_amt = x_test['Amount'].array.reshape(-1, 1)

# %% [markdown]
# Let's import <b>LogisticRegression</b> from the module <b>linear_model</b>.

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr_metrics = pd.DataFrame(columns = ['Features', 'Confusion Matrix', 'Precision', 'Recall', 'F1 Score'])

# %% [markdown]
# **Feature Scaling**
#
# In logistic regression, we will do feature scaling because we want accurate result of predictions. Here we will only scale the independent variable because dependent variable have only 0 and 1 values. Below is the code for it:

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train_1 = st_x.fit_transform(x_train)
x_test_1 = st_x.transform(x_test)

# %%
# We create a Logistic Regression object
classifier= LogisticRegression(random_state=0)
# We fit the model using the feature Time
classifier.fit(x_train_1, y_train)
#Predicting the test set result
y_pred= classifier.predict(x_test_1)

#Creating the Confusion matrix, Precision, Recall, F1-Score
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print('Confusion Matrix:\n', cm)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
lgr_metrics = lgr_metrics._append({'Features': ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9',
                                                'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19',
                                                'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
                                   'Confusion Matrix':cm, 'Precision':precision, 'Recall':recall, 'F1 Score':f1}, ignore_index = True)
# Out:
# Confusion Matrix:
#  [[71078    13]
#  [   47    64]]
# Precision: 0.8311688311688312
# Recall: 0.5765765765765766
# F1 Score: 0.6808510638297872

# %%
lgr_metrics
# Out:
#                                             Features         Confusion Matrix
# 0  [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10...  [[71078, 13], [47, 64]]  \
#
#    Precision    Recall  F1 Score
# 0   0.831169  0.576577  0.680851

# %%
df = data.drop(['Time', 'V8', 'V13', 'V15', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'], axis = 1)

# %%
#Extracting Independent and dependent Variable  
x_data_new = df.drop('Class', axis = 1)
y_data_new = df['Class']

# %%
from sklearn.model_selection import train_test_split

x_train_n, x_test_n, y_train_n, y_test_n = train_test_split(x_data_new, y_data_new, test_size=0.25, random_state=1)

print("number of test samples :", x_test_n.shape[0])
print("number of training samples:",x_train_n.shape[0])
# Out:
# number of test samples : 71202
# number of training samples: 213605

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train_1_n = st_x.fit_transform(x_train_n)
x_test_1_n = st_x.transform(x_test_n)

# %%
# We create a Logistic Regression object
classifier= LogisticRegression(random_state=0)
# We fit the model using the feature Time
classifier.fit(x_train_1_n, y_train_n)
#Predicting the test set result
y_pred_n = classifier.predict(x_test_1_n)

#Creating the Confusion matrix, Precision, Recall, F1-Score
cm = confusion_matrix(y_test_n, y_pred_n)
precision = precision_score(y_test_n, y_pred_n)
recall = recall_score(y_test_n, y_pred_n)
f1 = f1_score(y_test_n, y_pred_n)
print('Confusion Matrix:\n', cm)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
lgr_metrics = lgr_metrics._append({'Features': ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V9',
                                                'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18'],
                                   'Confusion Matrix':cm, 'Precision':precision, 'Recall':recall, 'F1 Score':f1}, ignore_index = True)
# Out:
# Confusion Matrix:
#  [[71079    12]
#  [   47    64]]
# Precision: 0.8421052631578947
# Recall: 0.5765765765765766
# F1 Score: 0.6844919786096256

# %%
lgr_metrics
# Out:
#                                             Features         Confusion Matrix
# 0  [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10...  [[71078, 13], [47, 64]]  \
# 1  [V1, V2, V3, V4, V5, V6, V7, V9, V10, V11, V12...  [[71079, 12], [47, 64]]
#
#    Precision    Recall  F1 Score
# 0   0.831169  0.576577  0.680851
# 1   0.842105  0.576577  0.684492
